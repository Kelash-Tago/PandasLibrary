# %%
salary=int(input("enter your salary: "))
print("your tax rate : ")
if salary<30000:
    print("5%")
elif salary>=30000 and salary<70000:
    print("15%")
else:
    print("25%")
# Out:
# enter your salary:  400000
# your tax rate :
# 25%

# %%
x=["apple","banana"]
y=["apple","banana"]
z=x
print(x is z)
print(x is y)
print(x==y)
# Out:
# True
# False
# True

# %%
x=["apple","banana","Orange","Mango"]
print("orange" in x)
print("Orange" in x)
print("length of the list: ", len(x))
print("index 1: ",x[1])
print("index -2: ",x[-2])
print(x[1:3])
print(x[:2])
# Out:
# False
# True
# length of the list:  4
# index 1:  banana
# index -2:  Orange
# ['banana', 'Orange']
# ['apple', 'banana']

# %%
#print list in reverse
list=[1,3,4,5,6,6,7]
reverse=list[::-1]
print(reverse)
# Out:
# [7, 6, 6, 5, 4, 3, 1]

# %%
list=["Pakistan","India","Iran"]
print(list)
if "Iran" in list:
    print("yes it is present replacing it with Iraq")
    list[2]="Iraq"
else:
    print("no it is not present")
print(list)
# Out:
# ['Pakistan', 'India', 'Iran']
# yes it is present replacing it with Iraq
# ['Pakistan', 'India', 'Iraq']

# %%
list=["Pakistan","India","Iran"]
print(list)
list[1:3]=["Bangladesh","UAE"]
print(list)
list.remove("UAE")# in rempove we give value
print(list)
list.insert(0,"USA")
list.append("UK")
print(list)
list.pop(0) #in pop we give indexnumber
print(list)
list.pop() #it remove last element
# Out:
# ['Pakistan', 'India', 'Iran']
# ['Pakistan', 'Bangladesh', 'UAE']
# ['Pakistan', 'Bangladesh']
# ['USA', 'Pakistan', 'Bangladesh', 'UK']
# ['Pakistan', 'Bangladesh', 'UK']

# %%
# clear vs delete function
list=["Pakistan","India","Iran"]
list.clear
