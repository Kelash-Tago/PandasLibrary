# %%
import pandas as pd
data=pd.read_json("data.json")
print(data)
# Out:
#       name rating                   feedback age
# 0    Alice      5            Great product!!  25
# 1      Bob   four       ok but late Delivery  30
# 2  Charlie    two             BAD EXPERIENCE
# 3    Diana      5                  Loved it!  28
# 4      Eve    3.5  Average - could be better  20
# 5    Alice      5       Great product again!  25

# %%
print(data.head(2))
# Out:
#     name rating              feedback age
# 0  Alice      5       Great product!!  25
# 1    Bob   four  ok but late Delivery  30
